# %% [markdown]
# ## Unitree G1 - Router Connection
#
# Robot A
#
# 1. Connect to G1 LAN
#
# SSID: Conestoga-G1-5G
# Pass: Conest0gaG1
#
# 2. Point browser to: http://192.168.123.1/#/login
#
# Admin Pass: Conest0ga.R0ut3r
#
# 3. On **Internet** menu
#
# Connect to CCSecure
# (switch network if already connected)
#
# 4. Connect to G1
#
# Open BASH terminal
# $ ssh unitree@192.168.123.164
# $ unitree@192.168.123.164's password: 123
# $
#
#
# Robot B
#
# 1. Connect to G1 LAN
#
# SSID: Conestoga-G1-5G
# Pass: Conest0gaG1
#
# 2. Point browser to: http://192.168.123.1/#/login
#
# Admin Pass: Conest0ga.R0ut3r
#
# 3. On **Internet** menu
#
# Connect to CCSecure
# (switch network if already connected)
#
# 4. Connect to G1
#
# Open BASH terminal
# $ ssh unitree@192.168.123.164
# $ unitree@192.168.123.164's password: 123
# $
