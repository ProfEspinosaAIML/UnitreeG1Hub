# %% [markdown]
# # FingerMotion7DF - PrototypeOne - Demo5
#
# Documentation for 'g1_fingers_arms_sdk_dds_demo2.py' and 'g1_fingers_arms_sdk_dds_demo2.mp4'

# %% [markdown]
# ## Overview
#
# Final Track 1 showcase integrating validated arm control and validated right-hand Dex3 control.

# %% [markdown]
# ## Best Current Right-Hand Model
#
# - q0 = Thumb Rotation
# - q1 = Unknown
# - q2 = Unknown
# - q3+q4 = Right Finger
# - q5+q6 = Left Finger

# %% [markdown]
# ## Arm Model
#
# Left arm joints 15-21
#
# Right arm joints 22-28
#
# SDK enable joint = 29

# %% [markdown]
# ## DDS Topics
#
# Hand command: rt/dex3/right/cmd
#
# Hand state: rt/lf/dex3/right/state
#
# Arm command: rt/arm_sdk
#
# Arm state: rt/lowstate

# %% [markdown]
# ## Showcase Stages
#
# 1. Wake Up
# 2. Finger Introduction
# 3. Thumb Demonstration
# 4. Dexterity Routine
# 5. Arm Presentation
# 6. Simulated Grasp
# 7. Concurrent Motion
# 8. Technical Finale
# 9. Final Presentation

# %% [markdown]
# ## Engineering Notes
#
# This demo serves as the final validated baseline before Track 2 reverse-engineering.
