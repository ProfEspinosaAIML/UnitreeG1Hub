# %% [markdown]
# # FingerMotion7DF - PrototypeOne - Demo4
#
# Documentation for `g1_fingers_arms_sdk_dds_demo1.py` and the video `g1_fingers_arms_sdk_dds_demo1.mp4`.

# %% [markdown]
# ## Current Best Arm Model
#
# Arm joints 15–28 are controlled through `rt/arm_sdk`. Joint 29 enables/disables SDK arm control.

# %% [markdown]
# ## Current Best Right-Hand Model
#
# - q0 = thumb rotation
# - q1 = unknown
# - q2 = unknown
# - q3+q4 = right finger
# - q5+q6 = left finger
#
# `1.0 ≈ closed`, `0.0 ≈ open`.

# %% [markdown]
# ## DDS Topics
#
# - `rt/arm_sdk`
# - `rt/lowstate`
# - `rt/dex3/right/cmd`
# - `rt/lf/dex3/right/state`

# %% [markdown]
# ## Demo4 Choreography
#
# 1. Wake Up
# 2. Forward Presentation
# 3. Right Finger
# 4. Left Finger
# 5. Thumb
# 6. Wide Presentation
# 7. Dexterity
# 8. Thumb Sweep
# 9. Simulated Grasp
# 10. Release
# 11. Return to Presentation
# 12. Return Home
# 13. Release SDK

# %% [markdown]
# ## Simulated Grasp
#
# Current best grasp illusion:
#
# ```python
# thumb=-1.0
# right=1.0
# left=1.0
# ```

# %% [markdown]
# ## Future Work
#
# Track 2: Reverse engineer the left hand and discover whether a thumb curl DOF exists.
