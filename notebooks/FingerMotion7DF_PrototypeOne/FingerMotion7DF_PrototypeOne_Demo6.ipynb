# %% [markdown]
# # FingerMotion7DF - PrototypeOne - Demo6
#
# Documentation for **g1_fingers_arms_sdk_dds_demo3.py** and 'g1_fingers_arms_sdk_dds_demo6.mp4'

# %% [markdown]
# ## Overview
#
# Final Track 1 showcase integrating validated G1 arm control and validated LEFT-hand Dex3 control.

# %% [markdown]
# ## Left Hand Blueprint
#
# ```
#                 THUMB
#                   |
#                  q0
#                   |
#
#       Finger A            Finger B
#
#       q3 -> Base          q5 -> Base
#       q4 -> Tip           q6 -> Tip
# ```
#
# Finger A = finger left of thumb when viewing palm.
#
# Finger B = finger right of thumb when viewing palm.

# %% [markdown]
# ## Left Hand Kinematic Map
#
# - q0 = thumb rotation
# - q1 = unused / inactive
# - q2 = unused / inactive
# - q3 = finger A base joint
# - q4 = finger A tip joint
# - q5 = finger B base joint
# - q6 = finger B tip joint

# %% [markdown]
# ## Final Left-Hand Map
#
# | Channel | Function |
# |----------|----------|
# | q0 | Thumb rotation |
# | q1 | Inactive / firmware-reserved |
# | q2 | Inactive / firmware-reserved |
# | q3 | Finger A base joint |
# | q4 | Finger A tip joint |
# | q5 | Finger B base joint |
# | q6 | Finger B tip joint |

# %% [markdown]
# ## Arm Model
#
# Left arm joints 15-21
#
# Right arm joints 22-28
#
# SDK enable joint = 29

# %% [markdown]
# ## DDS Topics
#
# Hand command: rt/dex3/left/cmd
#
# Hand state: rt/lf/dex3/left/state
#
# Arm command: rt/arm_sdk
#
# Arm state: rt/lowstate

# %% [markdown]
# ## Demo 3 Showcase Stages
#
# 1. Wake Up
# 2. Forward Presentation
# 3. Finger A Base Joint
# 4. Finger A Tip Joint
# 5. Finger A Full Curl
# 6. Finger B Base Joint
# 7. Finger B Tip Joint
# 8. Finger B Full Curl
# 9. Thumb Left
# 10. Thumb Right
# 11. Pinch Grasp
# 12. Dexterity Routine
# 13. Wide Presentation
# 14. Thumb Sweep
# 15. Final Pinch
# 16. Release
# 17. Return To Presentation
# 18. Return Home
# 19. Release Arm SDK

# %% [markdown]
# ## Engineering Notes
#
# This notebook documents the validated left-hand reverse-engineering effort and serves as the baseline for future grasping and RL experiments.
