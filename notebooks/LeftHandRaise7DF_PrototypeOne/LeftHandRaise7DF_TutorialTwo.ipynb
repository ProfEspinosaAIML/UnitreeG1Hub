# %% [markdown]
# # LeftHandRaise7DF Tutorial Two
# ## From Physical G1 Control to Isaac Sim (Sim-to-Real Pipeline)
#
# **Level:** Graduate / RL-focused
#
# This notebook documents the full transformation from a physical robot controller to a dual-mode simulation + hardware control system.
#
# ![Image](../../images/LeftHandRaise7DF_TutorialTwo.png)

# %% [markdown]
# ## System Architecture
#
# ![Image](../../images/LeftHandRaise7DF_ControlLogic.png)

# %% [markdown]
# ## Phase 1
#
# Detailed explanation of transformation step 1.
#
# ### Key Concepts
# - Control abstraction
# - Sim-to-real mapping
# - System design implications
#
# ### Explanation
# Describe what changes were made and why.
#
# ### Diagram
# ```
# [Input] → [Transformation] → [Output]
# ```

# %% [markdown]
# ## Phase 2
#
# Detailed explanation of transformation step 2.
#
# ### Key Concepts
# - Control abstraction
# - Sim-to-real mapping
# - System design implications
#
# ### Explanation
# Describe what changes were made and why.
#
# ### Diagram
# ```
# [Input] → [Transformation] → [Output]
# ```

# %% [markdown]
# ## Phase 3
#
# Detailed explanation of transformation step 3.
#
# ### Key Concepts
# - Control abstraction
# - Sim-to-real mapping
# - System design implications
#
# ### Explanation
# Describe what changes were made and why.
#
# ### Diagram
# ```
# [Input] → [Transformation] → [Output]
# ```

# %% [markdown]
# ## Phase 4
#
# Detailed explanation of transformation step 4.
#
# ### Key Concepts
# - Control abstraction
# - Sim-to-real mapping
# - System design implications
#
# ### Explanation
# Describe what changes were made and why.
#
# ### Diagram
# ```
# [Input] → [Transformation] → [Output]
# ```

# %% [markdown]
# ## Phase 5
#
# Detailed explanation of transformation step 5.
#
# ### Key Concepts
# - Control abstraction
# - Sim-to-real mapping
# - System design implications
#
# ### Explanation
# Describe what changes were made and why.
#
# ### Diagram
# ```
# [Input] → [Transformation] → [Output]
# ```

# %% [markdown]
# ## Phase 6
#
# Detailed explanation of transformation step 6.
#
# ### Key Concepts
# - Control abstraction
# - Sim-to-real mapping
# - System design implications
#
# ### Explanation
# Describe what changes were made and why.
#
# ### Diagram
# ```
# [Input] → [Transformation] → [Output]
# ```

# %% [markdown]
# ## Phase 7
#
# Detailed explanation of transformation step 7.
#
# ### Key Concepts
# - Control abstraction
# - Sim-to-real mapping
# - System design implications
#
# ### Explanation
# Describe what changes were made and why.
#
# ### Diagram
# ```
# [Input] → [Transformation] → [Output]
# ```

# %% [markdown]
# ## Phase 8
#
# Detailed explanation of transformation step 8.
#
# ### Key Concepts
# - Control abstraction
# - Sim-to-real mapping
# - System design implications
#
# ### Explanation
# Describe what changes were made and why.
#
# ### Diagram
# ```
# [Input] → [Transformation] → [Output]
# ```

# %% [markdown]
# ## Phase 9
#
# Detailed explanation of transformation step 9.
#
# ### Key Concepts
# - Control abstraction
# - Sim-to-real mapping
# - System design implications
#
# ### Explanation
# Describe what changes were made and why.
#
# ### Diagram
# ```
# [Input] → [Transformation] → [Output]
# ```

# %% [markdown]
# ## Phase 10
#
# Detailed explanation of transformation step 10.
#
# ### Key Concepts
# - Control abstraction
# - Sim-to-real mapping
# - System design implications
#
# ### Explanation
# Describe what changes were made and why.
#
# ### Diagram
# ```
# [Input] → [Transformation] → [Output]
# ```

# %% [markdown]
# ## Phase 11
#
# Detailed explanation of transformation step 11.
#
# ### Key Concepts
# - Control abstraction
# - Sim-to-real mapping
# - System design implications
#
# ### Explanation
# Describe what changes were made and why.
#
# ### Diagram
# ```
# [Input] → [Transformation] → [Output]
# ```

# %% [markdown]
# ## Phase 12
#
# Detailed explanation of transformation step 12.
#
# ### Key Concepts
# - Control abstraction
# - Sim-to-real mapping
# - System design implications
#
# ### Explanation
# Describe what changes were made and why.
#
# ### Diagram
# ```
# [Input] → [Transformation] → [Output]
# ```

# %% [markdown]
# ## Phase 13
#
# Detailed explanation of transformation step 13.
#
# ### Key Concepts
# - Control abstraction
# - Sim-to-real mapping
# - System design implications
#
# ### Explanation
# Describe what changes were made and why.
#
# ### Diagram
# ```
# [Input] → [Transformation] → [Output]
# ```

# %% [markdown]
# ## Phase 14
#
# Detailed explanation of transformation step 14.
#
# ### Key Concepts
# - Control abstraction
# - Sim-to-real mapping
# - System design implications
#
# ### Explanation
# Describe what changes were made and why.
#
# ### Diagram
# ```
# [Input] → [Transformation] → [Output]
# ```

# %% [markdown]
# ## Phase 15
#
# Detailed explanation of transformation step 15.
#
# ### Key Concepts
# - Control abstraction
# - Sim-to-real mapping
# - System design implications
#
# ### Explanation
# Describe what changes were made and why.
#
# ### Diagram
# ```
# [Input] → [Transformation] → [Output]
# ```

# %% [markdown]
# ## Core Controller Code

# %%
# g1_hand7_isaacsim.py (excerpt)
USE_ISAAC_SIM = True

def apply_targets(targets):
    if USE_ISAAC_SIM:
        sim_robot.set_joint_positions(names, targets)
    else:
        publish_lowcmd(targets)

# %% [markdown]
# ## Simulation Runner

# %%
# run_g1_sim.py (excerpt)
add_reference_to_stage(usd_path, "/World/G1")
robot = Articulation(prim_path="/World/G1")

# %% [markdown]
# ## Executing the simulator
#
# Assuming you have the following setup:
#
# ```
#     Directory: C:\
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# d-----         3/20/2026   4:39 AM                cyclonedds-11.0.1
# d-----         4/17/2024   8:20 AM                Dell
# d-----         4/28/2026  12:52 PM                Documentation
# d-----         3/13/2026  10:43 AM                inetpub
# d-----         4/28/2026  12:49 PM                IsaacAssets
# d-----         3/18/2026   7:10 PM                IsaacLab
# d-----         3/18/2026   6:27 PM                IsaacSim
# d-----         3/16/2026   2:39 AM                IsaacSim5.0
# d-----         3/24/2026  10:11 AM                Miniconda3
# ```
#
# > Execute the simulator:
#
# ```PowerShell
# PS C:\> cd C:\Documentation\UnitreeG1Hub\src\LeftHandRaise7DF_PrototypeOne\
# PS C:\Documentation\UnitreeG1Hub\src\LeftHandRaise7DF_PrototypeOne> C:\IsaacSim\python.bat .\run_g1_sim.py
# ```
# The simulator should start:
#
# ![Image](../../images/LeftHandRaise7DF_Sim.PNG)

# %% [markdown]
# ## Troubleshooting
#
# - Robot collapses → raise initial pose
# - Joint mismatch → fix naming map
# - No articulation → check USD dependencies

# %% [markdown]
# ## Reinforcement Learning Extension
#
# Next steps:
# - Define observation space
# - Define action space
# - Add reward function
# - Integrate PPO training
